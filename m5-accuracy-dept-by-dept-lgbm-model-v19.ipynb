# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np, pandas as pd, matplotlib.pyplot as plt

from hyperopt import hp, tpe, fmin, Trials

from sklearn.preprocessing import OrdinalEncoder, MinMaxScaler, StandardScaler
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.model_selection import cross_val_score, StratifiedKFold, train_test_split

import lightgbm as lgb

import os, gc, random, time, pickle, json
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/m5-forecasting-accuracy/calendar.csv
# /kaggle/input/m5-forecasting-accuracy/sell_prices.csv
# /kaggle/input/m5-forecasting-accuracy/sales_train_validation.csv
# /kaggle/input/m5-forecasting-accuracy/sample_submission.csv
# /kaggle/input/m5-cal-mod2/calendar_mod_2.csv

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %% [markdown]
# ## Load data

# %%
def cal_transform(df):
#     sc = MinMaxScaler(feature_range=(0, 1))
    sc = StandardScaler()
    cols = ['wholesale_inventory','wholesale_sales','retai_t_f_sales','urban_cpi','cpi','unemp_rate','ppi','gdp']
    df_scaled = sc.fit_transform(df[cols])
    df_scaled = pd.DataFrame(df_scaled)
    for i, col in enumerate(cols):
        df[col] = df_scaled[i]
    return df

# %%
path = "../input/m5-forecasting-accuracy"

calendar = pd.read_csv(os.path.join('/kaggle/input/m5-cal-mod2/calendar_mod_2.csv'))
calendar = cal_transform(calendar).pipe(reduce_mem_usage)
print('Calendar has {} rows and {} columns'.format(calendar.shape[0], calendar.shape[1]))
selling_prices = pd.read_csv(os.path.join(path, "sell_prices.csv"))
print('selling_prices has {} rows and {} columns'.format(selling_prices.shape[0], selling_prices.shape[1]))
sample_submission = pd.read_csv(os.path.join(path, "sample_submission.csv"))
print('sample_submission has {} rows and {} columns'.format(sample_submission.shape[0], sample_submission.shape[1]))
sales = pd.read_csv(os.path.join(path, "sales_train_validation.csv"))
print('sales has {} rows and {} columns'.format(sales.shape[0], sales.shape[1]))
# Out:
# Mem. usage decreased to  0.15 Mb (54.0% reduction)
# Calendar has 1969 rows and 22 columns
# selling_prices has 6841121 rows and 4 columns
# sample_submission has 60980 rows and 29 columns
# sales has 30490 rows and 1919 columns

# %% [markdown]
# ## Prepare calendar data

# %%
def prep_calendar(df):
    # time features
    
    df['date'] = pd.to_datetime(df['date'])
    df['year'] = df['date'].dt.year
    df['month'] = df['date'].dt.month
    df['week'] = df['date'].dt.week
    df['day'] = df['date'].dt.day
    df['dayofweek'] = df['date'].dt.dayofweek
    df["is_weekend"] = df["dayofweek"].isin([5, 6]).astype(np.int8)
    df = df.drop(["date", "weekday", "event_type_1", "event_type_2"], axis=1)
    df = df.assign(d = df.d.str[2:].astype(int))
    to_ordinal = ["event_name_1", "event_name_2"] 
    df[to_ordinal] = df[to_ordinal].fillna("1")
    df[to_ordinal] = OrdinalEncoder(dtype="int").fit_transform(df[to_ordinal]) + 1
    to_int8 = ["wday", "month", "snap_CA", "snap_TX", "snap_WI"] + to_ordinal
    df[to_int8] = df[to_int8].astype("int8")
    
    return df

calendar = prep_calendar(calendar)
# calendar.head()

# %%
penalty = 1.15 
# Define custom asymmetric MSE loss functions since the penalty of incorrect prediction is not symmetric in regards to RMSE's relation to competition score WRMSSE
# Custom loss which gives [1.15] times more penalty when the true targets are more than predictions as compared to less

# Objective function (fobj)
# The training loss is the function that is optimized using gradient descent.
# The training loss typically needs to be a function that has a convex gradient (first derivative) and hessian (second derivative). 
# It is also preferably continuous, finite, and non-zero. The last one is important because sections where the function is zero can freeze gradient descent.
def custom_asymmetric_train(y_pred, y_true):
    y_true = y_true.get_label()
    residual = (y_true - y_pred).astype("float")
    grad = np.where(residual < 0, -2 * residual, -2 * residual * penalty)
    hess = np.where(residual < 0, 2, 2 * penalty)
    return grad, hess

# Evaluation metric (feval)
# The validation loss is used to tune hyper-parameters.
# The validation loss can be non-convex, non-differentiable, and discontinuous.
def custom_asymmetric_valid(y_pred, y_true):
    y_true = y_true.get_label()
    residual = (y_true - y_pred).astype("float")
    loss = np.where(residual < 0, (residual ** 2) , (residual ** 2) * penalty) 
    return "custom_asymmetric_eval", np.mean(loss), False

# %%
def optimize_parameters(df, max_evals=20, dept="FOODS_1"):
    # define fixed hyperparameters
    params = {
            'boosting_type': 'gbdt',  #goss, dart, gbdt
            'objective': 'tweedie',  #poisson, tweedie, rmse
            'tweedie_variance_power': 1.1,
            'metric': 'rmcustomse',
            'subsample': 0.5,
            'subsample_freq': 1,
            'learning_rate': 0.03,
            'feature_fraction': 0.5,
            'max_bin': 100,
            'n_estimators': 1400,
            'boost_from_average': False,
            'verbose': -1
            }
    
    # define floating hyperparameters
    space = {
        'max_depth': hp.quniform('max_depth', 3, 12, 1),
        'num_leaves': hp.quniform('num_leaves', 10, 2040, 20),
        'min_data_in_leaf': hp.quniform('min_data_in_leaf', 10, 2040, 20),
            }
    
    # define the objective function to optimize the hyperparameters
    def objective(floating_params):
        params['max_depth'] = int(floating_params['max_depth'])
        params['num_leaves'] = int(floating_params['num_leaves'])
        params['min_data_in_leaf'] = int(floating_params['min_data_in_leaf'])
        print(params)
        regressor = lgb.LGBMRegressor(**params)
        
        x_sample = df.sample(int(df.shape[0]/50), random_state=SEED)
        x_train_sample, y_train_sample = x_sample[x], x_sample['demand']
        
        score = cross_val_score(regressor, x_train_sample, y_train_sample, cv=StratifiedKFold(),
                                scoring=make_scorer(mean_squared_error, greater_is_better=True)
                                ).mean()
        print("rmse {:.3f}".format(score))
        return score

    best = fmin(fn=objective,
                space=space,
                algo=tpe.suggest,
                max_evals=max_evals)
    
    params['num_iterations'] = num_iterations
    
    best['max_depth'] = int(best['max_depth'])
    best['num_leaves'] = int(best['num_leaves'])
    best['min_data_in_leaf'] = int(best['min_data_in_leaf'])
        
    with open(dept+'_params.txt', 'w') as file:
        file.write(json.dumps(params))
    
    return params

# %%
LAGS = [5, 7, 30]
WINDOWS = [7, 28, 56]
FIRST = 1914
LENGTH = 28
num_iterations = 2500 # num boosting cycles for LGBM
ESR = 150 # early_stopping_rounds
VE = 25 # verbose_eval
SEED = 66

def demand_features(df):
    """ Derive features from sales data and remove rows with missing values """
    for lag in LAGS:
        df[f'lag_t{lag}'] = df.groupby('id')['demand'].transform(lambda x: x.shift(lag)).astype("float32")
        for w in WINDOWS:
            df[f'rolling_mean_lag{lag}_w{w}'] = df.groupby('id')[f'lag_t{lag}'].transform(lambda x: x.rolling(w).mean()).astype("float32")
#             df[f'rolling_skew_{lag}_w{w}'] = df.groupby(["id"])[f'lag_t{lag}'].transform(lambda x: x.rolling(w).skew()).astype("float32")
    return df

def demand_features_eval(df):
    """ Same as demand_features but for the step-by-step evaluation """
    out = df.groupby('id', sort=False).last()
    for lag in LAGS:
        out[f'lag_t{lag}'] = df.groupby('id', sort=False)['demand'].nth(-lag-1).astype("float32")
        for w in WINDOWS:
            out[f'rolling_mean_lag{lag}_w{w}'] = df.groupby('id', sort=False)['demand'].nth(list(range(-lag-w, -lag))).groupby('id', sort=False).mean().astype("float32")
#             out[f'rolling_skew_{lag}_w{w}'] = df.groupby('id', sort=False)['demand'].nth(list(range(-lag-w, -lag))).groupby('id', sort=False).skew().astype("float32")
    return out.reset_index()

def prep_data(df, drop_d=1000, dept_id="FOODS_1"):
    """ Prepare model data sets """
    
    print(f"\nWorking on dept {dept_id}")
    # Filter on dept_id
    df = df[df.dept_id == dept_id]
    df = df.drop(["dept_id", "cat_id"], axis=1)
    
    # Kick out old dates
    df = df.drop(["d_" + str(i+1) for i in range(drop_d)], axis=1)

    # Reshape to long
    df = df.assign(id=df.id.str.replace("_validation", ""))
    df = df.reindex(columns=df.columns.tolist() + ["d_" + str(FIRST + i) for i in range(2 * LENGTH)])
    df = df.melt(id_vars=["id", "item_id", "store_id", "state_id"], var_name='d', value_name='demand')
    df = df.assign(d=df.d.str[2:].astype("int64"),
                   demand=df.demand.astype("float32"))
    
    # Add demand features
    df = demand_features(df)
    
    # Remove rows with NAs
    df = df[df.d > (drop_d + max(LAGS) + max(WINDOWS))]
 
    # Join calendar & prices
    df = df.merge(calendar, how="left", on="d")
    df = df.merge(selling_prices, how="left", on=["store_id", "item_id", "wm_yr_wk"])
 
    # Add amount features
    df['amount'] = df['demand'] * df['sell_price']
#     gra = df.groupby(["store_id", "item_id"])["amount"]
#     df["amount_rel_diff"] = df.groupby(["store_id", "item_id"])["amount"].pct_change()
#     df['growing_amount'] = df['amount'] * (1 + df['amount_rel_diff']/100)
#     df["amount_cumrel"] = (gra.shift(0) - gra.cummin()) / (1 + gra.cummax() - gra.cummin())
    for lag in LAGS:
        df[f'amount_lag_t{lag}'] = df.groupby('id')['amount'].transform(lambda x: x.shift(lag)).astype("float32")
        for w in WINDOWS:
            df[f'rolling_mean_amount_lag{lag}_w{w}'] = df.groupby('id')[f'amount_lag_t{lag}'].transform(lambda x: x.rolling(w).mean()).astype("float32")
#             df[f'rolling_skew_amount_lag{lag}_w{w}'] = df.groupby('id')[f'amount_lag_t{lag}'].transform(lambda x: x.rolling(w).std()).astype("float32")
#     del gra
#     gc.collect()
    
    # Add price features
    df['lag_price_t1'] = df.groupby(['id'])['sell_price'].transform(lambda x: x.shift(1))
    df['price_change_t1'] = (df['lag_price_t1'] - df['sell_price']) / (df['lag_price_t1'])
    df['rolling_price_max_t365'] = df.groupby(['id'])['sell_price'].transform(lambda x: x.shift(1).rolling(365).max())
    df['price_change_t365'] = (df['rolling_price_max_t365'] - df['sell_price']) / (df['rolling_price_max_t365'])
    df['rolling_price_std_t7'] = df.groupby(['id'])['sell_price'].transform(lambda x: x.rolling(7).std())
    df['rolling_price_std_t28'] = df.groupby(['id'])['sell_price'].transform(lambda x: x.rolling(28).std())
    df.drop(['rolling_price_max_t365', 'lag_price_t1'], inplace = True, axis = 1)

    # We can do some basic aggregations
    gr = df.groupby(["store_id", "item_id"])["sell_price"]
    df["sell_price_rel_diff"] = gr.pct_change()
    df['growing_price'] = df['sell_price'] * (1 + df['sell_price_rel_diff']/100)
#     df["sell_price_roll_sd7"] = gr.transform(lambda x: x.rolling(7).std())
#     df["sell_price_cumrel"] = (gr.shift(0) - gr.cummin()) / (1 + gr.cummax() - gr.cummin())
    df['price_max'] = df.groupby(['store_id','item_id'])['sell_price'].transform('max')
    df['price_min'] = df.groupby(['store_id','item_id'])['sell_price'].transform('min')
    # and do price normalization (min/max scaling)
    df['price_norm'] = df['sell_price']/df['price_max']
    df.drop(['price_max'], inplace = True, axis = 1)
    df['price_std'] = df.groupby(['store_id','item_id'])['sell_price'].transform('std')
    df['price_mean'] = df.groupby(['store_id','item_id'])['sell_price'].transform('mean')
    del gr
    gc.collect()
    
    # Some items are can be inflation dependent
    # and some items are very "stable"
    df['price_nunique'] = df.groupby(['store_id','item_id'])['sell_price'].transform('nunique')
    df['item_nunique'] = df.groupby(['store_id','sell_price'])['item_id'].transform('nunique')

    # Now we can add price "momentum" (some sort of)
    # Shifted by week 
    # by month mean
    # by year mean
    df['price_momentum'] = df['sell_price']/df.groupby(['store_id','item_id'])['sell_price'].transform(lambda x: x.shift(1))
    df['price_momentum_m'] = df['sell_price']/df.groupby(['store_id','item_id','month'])['sell_price'].transform('mean')
    df['price_momentum_y'] = df['sell_price']/df.groupby(['store_id','item_id','year'])['sell_price'].transform('mean')
    del df['month'], df['year']
    df = df.drop(["wm_yr_wk"], axis=1)

    # Ordinal encoding of remaining categorical fields
    for v in ["item_id", "store_id", "state_id"]:
        df[v] = OrdinalEncoder(dtype="int").fit_transform(df[[v]]).astype("int16") + 1
    
    # Determine list of covariables
    x = list(set(df.columns) - {'id', 'd', 'demand', 'amount','wm_yr_wk'})
            
    # Split into test, valid, train
    test = df[df.d >= FIRST - max(LAGS) - max(WINDOWS)]
    df = df[df.d < FIRST]

    xtrain, xvalid, ytrain, yvalid = train_test_split(df[x], df["demand"], test_size=0.2, shuffle=True, random_state=SEED) 
    
    train = lgb.Dataset(xtrain, label = ytrain)
    valid = lgb.Dataset(xvalid, label = yvalid)

    return train, valid, test, x, df

# %%
def fit_model(train, valid, dept, update_hyperparameters=False):
    """ Fit LightGBM model """
     
    if (update_hyperparameters and os.path.exists('/kaggle/working/'+dept+'_params.txt')):
        with open(dept+'_params.txt') as params_file:    
            params = json.load(params_file)
    else:
        params = optimize_parameters(df, dept=dept)
        

    fit = lgb.train(params, 
                    train, 
                    num_boost_round = num_iterations, 
                    valid_sets = [valid], 
                    early_stopping_rounds = ESR,
                    verbose_eval = VE, 
                    fobj=custom_asymmetric_train, 
                    feval=custom_asymmetric_valid
                   )
    
#     # feature names
#     print('Feature names:', fit.feature_name())

#     # feature importances
#     print('Feature importances:', list(fit.feature_importance()))

#     print('Plot Feature Importance...')
#     fig, ax = plt.subplots(figsize=(12,8))
#     lgb.plot_importance(fit, ax=ax, precision=0, height=0.8, max_num_features=35, figsize=(8,12), title=dept)
#     ax.grid(False)
#     plt.title("LightGBM - Feature Importance on dept " +dept, fontsize=15)
#     plt.show()
    
    return fit

# %%
def pred_to_csv(fit, test, x, cols=sample_submission.columns, file="submission.csv", first=False):
    """ Calculate predictions and append to submission csv """
    
    # Recursive prediction
    for i, day in enumerate(np.arange(FIRST, FIRST + LENGTH)):
        test_day = demand_features_eval(test[(test.d <= day) & (test.d >= day - max(LAGS) - max(WINDOWS))])
        test.loc[test.d == day, "demand"] = fit.predict(test_day[x]) # * (1.025 + 0.01 * (day > 1928)) # https://www.kaggle.com/kyakovlev/m5-dark-magic & https://www.kaggle.com/mayer79/m5-forecast-poisson-loss
    
    # Prepare for reshaping
    test = test.assign(id=test.id + "_" + np.where(test.d < FIRST + LENGTH, "validation", "evaluation"),
                       F="F" + (test.d - FIRST + 1 - LENGTH * (test.d >= FIRST + LENGTH)).astype("str"))
    
    # Reshape
    submission = test.pivot(index="id", columns="F", values="demand").reset_index()[cols].fillna(0)
    
    # Export
    submission.to_csv(file, index=False, mode='w' if first else 'a', header=first)
    
    return True

# %% [markdown]
# ## The loop
#
# For each department id, we will now prepare the model data set (including reshaping of sales data and join of the other data sources) and fit boosted trees individually for this department id. The results are then written to a csv for submission.

# %%
for i, dept in enumerate(np.unique(sales.dept_id)):
    start = time.time()
    train, valid, test, x, df = prep_data(sales, 1000, dept) #1150
    fit = fit_model(train, valid, dept, update_hyperparameters=False)
    pred_to_csv(fit, test, x, first=(i==0))
    end = time.time()
    hours, rem = divmod(end-start, 3600)
    minutes, seconds = divmod(rem, 60)
    print("Time elapsed {:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),int(seconds)))
    gc.collect()
# Out:
# Working on dept FOODS_1
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 9, 'num_leaves': 1280, 'min_data_in_leaf': 920}
# rmse 4.509
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 3, 'num_leaves': 1280, 'min_data_in_leaf': 1920}
# rmse 4.752
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 9, 'num_leaves': 1360, 'min_data_in_leaf': 1780}
# rmse 4.679
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 100, 'min_data_in_leaf': 900}
# rmse 4.508
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 7, 'num_leaves': 1120, 'min_data_in_leaf': 200}
# rmse 4.443
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 5, 'num_leaves': 760, 'min_data_in_leaf': 740}
# rmse 4.499
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 8, 'num_leaves': 1120, 'min_data_in_leaf': 1680}
# rmse 4.628
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 5, 'num_leaves': 1360, 'min_data_in_leaf': 860}
# rmse 4.510
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 3, 'num_leaves': 1240, 'min_data_in_leaf': 880}
# rmse 4.514
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 5, 'num_leaves': 700, 'min_data_in_leaf': 1020}
# rmse 4.514
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 6, 'num_leaves': 1380, 'min_data_in_leaf': 1920}
# rmse 4.735
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 300, 'min_data_in_leaf': 1720}
# rmse 4.646
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 10, 'num_leaves': 1540, 'min_data_in_leaf': 1080}
# rmse 4.515
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 12, 'num_leaves': 1900, 'min_data_in_leaf': 1120}
# rmse 4.522
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 520, 'min_data_in_leaf': 1400}
# rmse 4.580
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 8, 'num_leaves': 1400, 'min_data_in_leaf': 60}
# rmse 4.518
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 10, 'num_leaves': 1740, 'min_data_in_leaf': 340}
# rmse 4.452
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 11, 'num_leaves': 160, 'min_data_in_leaf': 160}
# rmse 4.515
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 800, 'min_data_in_leaf': 620}
# rmse 4.455
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 920, 'min_data_in_leaf': 1660}
# rmse 4.628
# 100%|██████████| 20/20 [10:59<00:00, 32.97s/trial, best loss: 4.442820815707677]
# Training until validation scores don't improve for 150 rounds
# [25]	valid_0's custom_asymmetric_eval: 6.6269
# [50]	valid_0's custom_asymmetric_eval: 5.28904
# [75]	valid_0's custom_asymmetric_eval: 4.95088
# [100]	valid_0's custom_asymmetric_eval: 4.84933
# [125]	valid_0's custom_asymmetric_eval: 4.81106
# [150]	valid_0's custom_asymmetric_eval: 4.7934
# [175]	valid_0's custom_asymmetric_eval: 4.78298
# [200]	valid_0's custom_asymmetric_eval: 4.77196
# [225]	valid_0's custom_asymmetric_eval: 4.76244
# [250]	valid_0's custom_asymmetric_eval: 4.75457
# [275]	valid_0's custom_asymmetric_eval: 4.74631
# [300]	valid_0's custom_asymmetric_eval: 4.74049
# [325]	valid_0's custom_asymmetric_eval: 4.73368
# [350]	valid_0's custom_asymmetric_eval: 4.72907
# [375]	valid_0's custom_asymmetric_eval: 4.72465
# [400]	valid_0's custom_asymmetric_eval: 4.71937
# [425]	valid_0's custom_asymmetric_eval: 4.71421
# [450]	valid_0's custom_asymmetric_eval: 4.70922
# [475]	valid_0's custom_asymmetric_eval: 4.70595
# [500]	valid_0's custom_asymmetric_eval: 4.70265
# [525]	valid_0's custom_asymmetric_eval: 4.69835
# [550]	valid_0's custom_asymmetric_eval: 4.69441
# [575]	valid_0's custom_asymmetric_eval: 4.69165
# [600]	valid_0's custom_asymmetric_eval: 4.68891
# [625]	valid_0's custom_asymmetric_eval: 4.68554
# [650]	valid_0's custom_asymmetric_eval: 4.68182
# [675]	valid_0's custom_asymmetric_eval: 4.67918
# [700]	valid_0's custom_asymmetric_eval: 4.67694
# [725]	valid_0's custom_asymmetric_eval: 4.67352
# [750]	valid_0's custom_asymmetric_eval: 4.67063
# [775]	valid_0's custom_asymmetric_eval: 4.66792
# [800]	valid_0's custom_asymmetric_eval: 4.66538
# [825]	valid_0's custom_asymmetric_eval: 4.66275
# [850]	valid_0's custom_asymmetric_eval: 4.66084
# [875]	valid_0's custom_asymmetric_eval: 4.65831
# [900]	valid_0's custom_asymmetric_eval: 4.65678
# [925]	valid_0's custom_asymmetric_eval: 4.65409
# [950]	valid_0's custom_asymmetric_eval: 4.65191
# [975]	valid_0's custom_asymmetric_eval: 4.64989
# [1000]	valid_0's custom_asymmetric_eval: 4.64794
# [1025]	valid_0's custom_asymmetric_eval: 4.64525
# [1050]	valid_0's custom_asymmetric_eval: 4.6428
# [1075]	valid_0's custom_asymmetric_eval: 4.64128
# [1100]	valid_0's custom_asymmetric_eval: 4.63905
# [1125]	valid_0's custom_asymmetric_eval: 4.63705
# [1150]	valid_0's custom_asymmetric_eval: 4.63553
# [1175]	valid_0's custom_asymmetric_eval: 4.6337
# [1200]	valid_0's custom_asymmetric_eval: 4.6312
# [1225]	valid_0's custom_asymmetric_eval: 4.62958
# [1250]	valid_0's custom_asymmetric_eval: 4.62846
# [1275]	valid_0's custom_asymmetric_eval: 4.6268
# [1300]	valid_0's custom_asymmetric_eval: 4.62536
# [1325]	valid_0's custom_asymmetric_eval: 4.62466
# [1350]	valid_0's custom_asymmetric_eval: 4.62341
# [1375]	valid_0's custom_asymmetric_eval: 4.62172
# [1400]	valid_0's custom_asymmetric_eval: 4.62031
# Did not meet early stopping. Best iteration is:
# [1400]	valid_0's custom_asymmetric_eval: 4.62031
# Time elapsed 00:17:01.00
#
# Working on dept FOODS_2
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 5, 'num_leaves': 720, 'min_data_in_leaf': 1540}
# rmse 3.007
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 1000, 'min_data_in_leaf': 1020}
# rmse 2.999
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 6, 'num_leaves': 1080, 'min_data_in_leaf': 720}
# rmse 2.983
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 7, 'num_leaves': 1820, 'min_data_in_leaf': 1040}
# rmse 3.009
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 9, 'num_leaves': 520, 'min_data_in_leaf': 1140}
# rmse 3.003
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 5, 'num_leaves': 960, 'min_data_in_leaf': 740}
# rmse 2.990
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 8, 'num_leaves': 920, 'min_data_in_leaf': 560}
# rmse 3.000
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 7, 'num_leaves': 1560, 'min_data_in_leaf': 1120}
# rmse 3.008
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 9, 'num_leaves': 260, 'min_data_in_leaf': 620}
# rmse 2.996
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 480, 'min_data_in_leaf': 440}
# rmse 2.981
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 7, 'num_leaves': 1740, 'min_data_in_leaf': 1300}
# rmse 2.997
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 10, 'num_leaves': 460, 'min_data_in_leaf': 1300}
# rmse 3.007
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 1180, 'min_data_in_leaf': 1180}
# rmse 3.002
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 8, 'num_leaves': 640, 'min_data_in_leaf': 300}
# rmse 3.020
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 12, 'num_leaves': 240, 'min_data_in_leaf': 1120}
# rmse 3.000
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 12, 'num_leaves': 320, 'min_data_in_leaf': 760}
# rmse 3.002
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 11, 'num_leaves': 320, 'min_data_in_leaf': 1100}
# rmse 3.008
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 11, 'num_leaves': 1000, 'min_data_in_leaf': 20}
# rmse 3.297
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 10, 'num_leaves': 1740, 'min_data_in_leaf': 1040}
# rmse 3.003
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 5, 'num_leaves': 1740, 'min_data_in_leaf': 820}
# rmse 2.990
# 100%|██████████| 20/20 [23:34<00:00, 70.75s/trial, best loss: 2.9811663936313897]
# Training until validation scores don't improve for 150 rounds
# [25]	valid_0's custom_asymmetric_eval: 4.58992
# [50]	valid_0's custom_asymmetric_eval: 3.60675
# [75]	valid_0's custom_asymmetric_eval: 3.34317
# [100]	valid_0's custom_asymmetric_eval: 3.2558
# [125]	valid_0's custom_asymmetric_eval: 3.22062
# [150]	valid_0's custom_asymmetric_eval: 3.20379
# [175]	valid_0's custom_asymmetric_eval: 3.19229
# [200]	valid_0's custom_asymmetric_eval: 3.18284
# [225]	valid_0's custom_asymmetric_eval: 3.17368
# [250]	valid_0's custom_asymmetric_eval: 3.16743
# [275]	valid_0's custom_asymmetric_eval: 3.16203
# [300]	valid_0's custom_asymmetric_eval: 3.15692
# [325]	valid_0's custom_asymmetric_eval: 3.15315
# [350]	valid_0's custom_asymmetric_eval: 3.14951
# [375]	valid_0's custom_asymmetric_eval: 3.14506
# [400]	valid_0's custom_asymmetric_eval: 3.14142
# [425]	valid_0's custom_asymmetric_eval: 3.13938
# [450]	valid_0's custom_asymmetric_eval: 3.13734
# [475]	valid_0's custom_asymmetric_eval: 3.13493
# [500]	valid_0's custom_asymmetric_eval: 3.13211
# [525]	valid_0's custom_asymmetric_eval: 3.12967
# [550]	valid_0's custom_asymmetric_eval: 3.12816
# [575]	valid_0's custom_asymmetric_eval: 3.1266
# [600]	valid_0's custom_asymmetric_eval: 3.12488
# [625]	valid_0's custom_asymmetric_eval: 3.1228
# [650]	valid_0's custom_asymmetric_eval: 3.12113
# [675]	valid_0's custom_asymmetric_eval: 3.1192
# [700]	valid_0's custom_asymmetric_eval: 3.11765
# [725]	valid_0's custom_asymmetric_eval: 3.11539
# [750]	valid_0's custom_asymmetric_eval: 3.11384
# [775]	valid_0's custom_asymmetric_eval: 3.11225
# [800]	valid_0's custom_asymmetric_eval: 3.11013
# [825]	valid_0's custom_asymmetric_eval: 3.10927
# [850]	valid_0's custom_asymmetric_eval: 3.1078
# [875]	valid_0's custom_asymmetric_eval: 3.10584
# [900]	valid_0's custom_asymmetric_eval: 3.10532
# [925]	valid_0's custom_asymmetric_eval: 3.10428
# [950]	valid_0's custom_asymmetric_eval: 3.1035
# [975]	valid_0's custom_asymmetric_eval: 3.10306
# [1000]	valid_0's custom_asymmetric_eval: 3.10216
# [1025]	valid_0's custom_asymmetric_eval: 3.10131
# [1050]	valid_0's custom_asymmetric_eval: 3.09972
# [1075]	valid_0's custom_asymmetric_eval: 3.09843
# [1100]	valid_0's custom_asymmetric_eval: 3.09778
# [1125]	valid_0's custom_asymmetric_eval: 3.0966
# [1150]	valid_0's custom_asymmetric_eval: 3.09537
# [1175]	valid_0's custom_asymmetric_eval: 3.09414
# [1200]	valid_0's custom_asymmetric_eval: 3.09299
# [1225]	valid_0's custom_asymmetric_eval: 3.09181
# [1250]	valid_0's custom_asymmetric_eval: 3.09112
# [1275]	valid_0's custom_asymmetric_eval: 3.09013
# [1300]	valid_0's custom_asymmetric_eval: 3.08921
# [1325]	valid_0's custom_asymmetric_eval: 3.08829
# [1350]	valid_0's custom_asymmetric_eval: 3.08743
# [1375]	valid_0's custom_asymmetric_eval: 3.08599
# [1400]	valid_0's custom_asymmetric_eval: 3.08534
# Did not meet early stopping. Best iteration is:
# [1400]	valid_0's custom_asymmetric_eval: 3.08534
# Time elapsed 00:35:33.00
#
# Working on dept FOODS_3
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 7, 'num_leaves': 1640, 'min_data_in_leaf': 1600}
# rmse 10.467
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 6, 'num_leaves': 240, 'min_data_in_leaf': 1480}
# rmse 10.500
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 1480, 'min_data_in_leaf': 140}
# rmse 9.983
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 8, 'num_leaves': 1620, 'min_data_in_leaf': 1560}
# rmse 10.426
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 9, 'num_leaves': 1420, 'min_data_in_leaf': 1800}
# rmse 10.484
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 6, 'num_leaves': 960, 'min_data_in_leaf': 100}
# rmse 10.026
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 3, 'num_leaves': 1480, 'min_data_in_leaf': 1800}
# rmse 10.910
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 5, 'num_leaves': 140, 'min_data_in_leaf': 260}
# rmse 10.067
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 3, 'num_leaves': 180, 'min_data_in_leaf': 1260}
# rmse 10.665
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 3, 'num_leaves': 920, 'min_data_in_leaf': 560}
# rmse 10.323
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 11, 'num_leaves': 200, 'min_data_in_leaf': 100}
# rmse 10.182
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 9, 'num_leaves': 1440, 'min_data_in_leaf': 800}
# rmse 10.192
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 6, 'num_leaves': 1460, 'min_data_in_leaf': 1720}
# rmse 10.521
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 5, 'num_leaves': 1600, 'min_data_in_leaf': 1020}
# rmse 10.359
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 6, 'num_leaves': 1740, 'min_data_in_leaf': 1120}
# rmse 10.318
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 9, 'num_leaves': 280, 'min_data_in_leaf': 480}
# rmse 10.046
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 9, 'num_leaves': 700, 'min_data_in_leaf': 1740}
# rmse 10.472
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 7, 'num_leaves': 1180, 'min_data_in_leaf': 1500}
# rmse 10.434
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 3, 'num_leaves': 860, 'min_data_in_leaf': 1480}
# rmse 10.802
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 180, 'min_data_in_leaf': 480}
# rmse 10.198
# 100%|██████████| 20/20 [41:19<00:00, 123.99s/trial, best loss: 9.983411541318052]
# Training until validation scores don't improve for 150 rounds
# [25]	valid_0's custom_asymmetric_eval: 19.7708
# [50]	valid_0's custom_asymmetric_eval: 13.893
# [75]	valid_0's custom_asymmetric_eval: 12.2895
# [100]	valid_0's custom_asymmetric_eval: 11.7664
# [125]	valid_0's custom_asymmetric_eval: 11.5235
# [150]	valid_0's custom_asymmetric_eval: 11.3928
# [175]	valid_0's custom_asymmetric_eval: 11.3128
# [200]	valid_0's custom_asymmetric_eval: 11.2484
# [225]	valid_0's custom_asymmetric_eval: 11.1954
# [250]	valid_0's custom_asymmetric_eval: 11.1558
# [275]	valid_0's custom_asymmetric_eval: 11.1229
# [300]	valid_0's custom_asymmetric_eval: 11.097
# [325]	valid_0's custom_asymmetric_eval: 11.0726
# [350]	valid_0's custom_asymmetric_eval: 11.0525
# [375]	valid_0's custom_asymmetric_eval: 11.0313
# [400]	valid_0's custom_asymmetric_eval: 11.0113
# [425]	valid_0's custom_asymmetric_eval: 10.9972
# [450]	valid_0's custom_asymmetric_eval: 10.9779
# [475]	valid_0's custom_asymmetric_eval: 10.9629
# [500]	valid_0's custom_asymmetric_eval: 10.9523
# [525]	valid_0's custom_asymmetric_eval: 10.9376
# [550]	valid_0's custom_asymmetric_eval: 10.9262
# [575]	valid_0's custom_asymmetric_eval: 10.9166
# [600]	valid_0's custom_asymmetric_eval: 10.9088
# [625]	valid_0's custom_asymmetric_eval: 10.9016
# [650]	valid_0's custom_asymmetric_eval: 10.8904
# [675]	valid_0's custom_asymmetric_eval: 10.8805
# [700]	valid_0's custom_asymmetric_eval: 10.8702
# [725]	valid_0's custom_asymmetric_eval: 10.8612
# [750]	valid_0's custom_asymmetric_eval: 10.851
# [775]	valid_0's custom_asymmetric_eval: 10.846
# [800]	valid_0's custom_asymmetric_eval: 10.8372
# [825]	valid_0's custom_asymmetric_eval: 10.83
# [850]	valid_0's custom_asymmetric_eval: 10.8222
# [875]	valid_0's custom_asymmetric_eval: 10.8161
# [900]	valid_0's custom_asymmetric_eval: 10.8075
# [925]	valid_0's custom_asymmetric_eval: 10.7995
# [950]	valid_0's custom_asymmetric_eval: 10.7931
# [975]	valid_0's custom_asymmetric_eval: 10.7857
# [1000]	valid_0's custom_asymmetric_eval: 10.7811
# [1025]	valid_0's custom_asymmetric_eval: 10.7722
# [1050]	valid_0's custom_asymmetric_eval: 10.7656
# [1075]	valid_0's custom_asymmetric_eval: 10.7573
# [1100]	valid_0's custom_asymmetric_eval: 10.7518
# [1125]	valid_0's custom_asymmetric_eval: 10.7471
# [1150]	valid_0's custom_asymmetric_eval: 10.7403
# [1175]	valid_0's custom_asymmetric_eval: 10.7348
# [1200]	valid_0's custom_asymmetric_eval: 10.7303
# [1225]	valid_0's custom_asymmetric_eval: 10.7235
# [1250]	valid_0's custom_asymmetric_eval: 10.7192
# [1275]	valid_0's custom_asymmetric_eval: 10.7121
# [1300]	valid_0's custom_asymmetric_eval: 10.7087
# [1325]	valid_0's custom_asymmetric_eval: 10.7053
# [1350]	valid_0's custom_asymmetric_eval: 10.7012
# [1375]	valid_0's custom_asymmetric_eval: 10.6978
# [1400]	valid_0's custom_asymmetric_eval: 10.6926
# Did not meet early stopping. Best iteration is:
# [1400]	valid_0's custom_asymmetric_eval: 10.6926
# Time elapsed 01:06:40.00
#
# Working on dept HOBBIES_1
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 7, 'num_leaves': 320, 'min_data_in_leaf': 1760}
# rmse 4.269
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 7, 'num_leaves': 1200, 'min_data_in_leaf': 400}
# rmse 4.270
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 10, 'num_leaves': 1940, 'min_data_in_leaf': 80}
# rmse 4.328
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 11, 'num_leaves': 1800, 'min_data_in_leaf': 1920}
# rmse 4.296
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 3, 'num_leaves': 1000, 'min_data_in_leaf': 1040}
# rmse 4.232
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 8, 'num_leaves': 300, 'min_data_in_leaf': 1140}
# rmse 4.259
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 1760, 'min_data_in_leaf': 1380}
# rmse 4.254
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 780, 'min_data_in_leaf': 280}
# rmse 4.212
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 10, 'num_leaves': 660, 'min_data_in_leaf': 1480}
# rmse 4.261
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 1380, 'min_data_in_leaf': 1180}
# rmse 4.233
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 6, 'num_leaves': 100, 'min_data_in_leaf': 1540}
# rmse 4.269
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 3, 'num_leaves': 680, 'min_data_in_leaf': 920}
# rmse 4.216
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 7, 'num_leaves': 1920, 'min_data_in_leaf': 1380}
# rmse 4.256
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 10, 'num_leaves': 940, 'min_data_in_leaf': 1040}
# rmse 4.247
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 6, 'num_leaves': 1880, 'min_data_in_leaf': 940}
# rmse 4.219
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 8, 'num_leaves': 180, 'min_data_in_leaf': 1300}
# rmse 4.272
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 1620, 'min_data_in_leaf': 1540}
# rmse 4.276
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 11, 'num_leaves': 980, 'min_data_in_leaf': 1960}
# rmse 4.294
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 7, 'num_leaves': 600, 'min_data_in_leaf': 800}
# rmse 4.210
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 5, 'num_leaves': 1320, 'min_data_in_leaf': 1120}
# rmse 4.247
# 100%|██████████| 20/20 [21:49<00:00, 65.48s/trial, best loss: 4.210095520318471]
# Training until validation scores don't improve for 150 rounds
# [25]	valid_0's custom_asymmetric_eval: 4.5719
# [50]	valid_0's custom_asymmetric_eval: 4.03167
# [75]	valid_0's custom_asymmetric_eval: 3.89365
# [100]	valid_0's custom_asymmetric_eval: 3.85478
# [125]	valid_0's custom_asymmetric_eval: 3.83955
# [150]	valid_0's custom_asymmetric_eval: 3.83176
# [175]	valid_0's custom_asymmetric_eval: 3.82801
# [200]	valid_0's custom_asymmetric_eval: 3.82401
# [225]	valid_0's custom_asymmetric_eval: 3.82068
# [250]	valid_0's custom_asymmetric_eval: 3.81801
# [275]	valid_0's custom_asymmetric_eval: 3.81463
# [300]	valid_0's custom_asymmetric_eval: 3.81325
# [325]	valid_0's custom_asymmetric_eval: 3.81091
# [350]	valid_0's custom_asymmetric_eval: 3.80909
# [375]	valid_0's custom_asymmetric_eval: 3.80764
# [400]	valid_0's custom_asymmetric_eval: 3.80568
# [425]	valid_0's custom_asymmetric_eval: 3.80495
# [450]	valid_0's custom_asymmetric_eval: 3.80412
# [475]	valid_0's custom_asymmetric_eval: 3.8027
# [500]	valid_0's custom_asymmetric_eval: 3.80195
# [525]	valid_0's custom_asymmetric_eval: 3.80171
# [550]	valid_0's custom_asymmetric_eval: 3.80095
# [575]	valid_0's custom_asymmetric_eval: 3.8005
# [600]	valid_0's custom_asymmetric_eval: 3.8
# [625]	valid_0's custom_asymmetric_eval: 3.79912
# [650]	valid_0's custom_asymmetric_eval: 3.79904
# [675]	valid_0's custom_asymmetric_eval: 3.79853
# [700]	valid_0's custom_asymmetric_eval: 3.79799
# [725]	valid_0's custom_asymmetric_eval: 3.79745
# [750]	valid_0's custom_asymmetric_eval: 3.79682
# [775]	valid_0's custom_asymmetric_eval: 3.79614
# [800]	valid_0's custom_asymmetric_eval: 3.79587
# [825]	valid_0's custom_asymmetric_eval: 3.79571
# [850]	valid_0's custom_asymmetric_eval: 3.79495
# [875]	valid_0's custom_asymmetric_eval: 3.79447
# [900]	valid_0's custom_asymmetric_eval: 3.79455
# [925]	valid_0's custom_asymmetric_eval: 3.79409
# [950]	valid_0's custom_asymmetric_eval: 3.79363
# [975]	valid_0's custom_asymmetric_eval: 3.79347
# [1000]	valid_0's custom_asymmetric_eval: 3.79314
# [1025]	valid_0's custom_asymmetric_eval: 3.79347
# [1050]	valid_0's custom_asymmetric_eval: 3.79339
# [1075]	valid_0's custom_asymmetric_eval: 3.79339
# [1100]	valid_0's custom_asymmetric_eval: 3.79311
# [1125]	valid_0's custom_asymmetric_eval: 3.79276
# [1150]	valid_0's custom_asymmetric_eval: 3.79277
# [1175]	valid_0's custom_asymmetric_eval: 3.79288
# [1200]	valid_0's custom_asymmetric_eval: 3.79253
# [1225]	valid_0's custom_asymmetric_eval: 3.79233
# [1250]	valid_0's custom_asymmetric_eval: 3.79185
# [1275]	valid_0's custom_asymmetric_eval: 3.79178
# [1300]	valid_0's custom_asymmetric_eval: 3.79197
# [1325]	valid_0's custom_asymmetric_eval: 3.79146
# [1350]	valid_0's custom_asymmetric_eval: 3.79153
# [1375]	valid_0's custom_asymmetric_eval: 3.79127
# [1400]	valid_0's custom_asymmetric_eval: 3.79105
# Did not meet early stopping. Best iteration is:
# [1390]	valid_0's custom_asymmetric_eval: 3.79082
# Time elapsed 00:34:07.00
#
# Working on dept HOBBIES_2
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 8, 'num_leaves': 280, 'min_data_in_leaf': 1060}
# rmse 0.733
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 3, 'num_leaves': 880, 'min_data_in_leaf': 1560}
# rmse 0.732
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 10, 'num_leaves': 20, 'min_data_in_leaf': 1060}
# rmse 0.733
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 10, 'num_leaves': 1720, 'min_data_in_leaf': 1980}
# rmse 0.735
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 5, 'num_leaves': 540, 'min_data_in_leaf': 600}
# rmse 0.735
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 7, 'num_leaves': 1040, 'min_data_in_leaf': 700}
# rmse 0.736
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 7, 'num_leaves': 1020, 'min_data_in_leaf': 920}
# rmse 0.734
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 11, 'num_leaves': 1140, 'min_data_in_leaf': 1840}
# rmse 0.732
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 12, 'num_leaves': 1520, 'min_data_in_leaf': 540}
# rmse 0.738
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 500, 'min_data_in_leaf': 900}
# rmse 0.733
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 9, 'num_leaves': 1220, 'min_data_in_leaf': 560}
# rmse 0.737
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 9, 'num_leaves': 1360, 'min_data_in_leaf': 60}
# rmse 0.763
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 8, 'num_leaves': 1860, 'min_data_in_leaf': 360}
# rmse 0.745
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 10, 'num_leaves': 400, 'min_data_in_leaf': 980}
# rmse 0.734
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 12, 'num_leaves': 1680, 'min_data_in_leaf': 820}
# rmse 0.734
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 11, 'num_leaves': 720, 'min_data_in_leaf': 1260}
# rmse 0.731
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 8, 'num_leaves': 1420, 'min_data_in_leaf': 280}
# rmse 0.744
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 10, 'num_leaves': 1140, 'min_data_in_leaf': 80}
# rmse 0.763
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 800, 'min_data_in_leaf': 1200}
# rmse 0.731
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 6, 'num_leaves': 1080, 'min_data_in_leaf': 2020}
# rmse 0.734
# 100%|██████████| 20/20 [08:54<00:00, 26.71s/trial, best loss: 0.7308089545415013]
# Training until validation scores don't improve for 150 rounds
# [25]	valid_0's custom_asymmetric_eval: 0.704105
# [50]	valid_0's custom_asymmetric_eval: 0.67022
# [75]	valid_0's custom_asymmetric_eval: 0.66057
# [100]	valid_0's custom_asymmetric_eval: 0.656728
# [125]	valid_0's custom_asymmetric_eval: 0.654835
# [150]	valid_0's custom_asymmetric_eval: 0.653809
# [175]	valid_0's custom_asymmetric_eval: 0.653122
# [200]	valid_0's custom_asymmetric_eval: 0.652638
# [225]	valid_0's custom_asymmetric_eval: 0.652118
# [250]	valid_0's custom_asymmetric_eval: 0.651673
# [275]	valid_0's custom_asymmetric_eval: 0.651365
# [300]	valid_0's custom_asymmetric_eval: 0.651061
# [325]	valid_0's custom_asymmetric_eval: 0.650788
# [350]	valid_0's custom_asymmetric_eval: 0.650525
# [375]	valid_0's custom_asymmetric_eval: 0.650301
# [400]	valid_0's custom_asymmetric_eval: 0.650044
# [425]	valid_0's custom_asymmetric_eval: 0.649904
# [450]	valid_0's custom_asymmetric_eval: 0.649619
# [475]	valid_0's custom_asymmetric_eval: 0.649435
# [500]	valid_0's custom_asymmetric_eval: 0.649268
# [525]	valid_0's custom_asymmetric_eval: 0.649135
# [550]	valid_0's custom_asymmetric_eval: 0.649018
# [575]	valid_0's custom_asymmetric_eval: 0.648848
# [600]	valid_0's custom_asymmetric_eval: 0.648725
# [625]	valid_0's custom_asymmetric_eval: 0.648605
# ...
# rmse 3.238
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 7, 'num_leaves': 20, 'min_data_in_leaf': 980}
# rmse 3.220
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 11, 'num_leaves': 1480, 'min_data_in_leaf': 1160}
# rmse 3.227
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 3, 'num_leaves': 1480, 'min_data_in_leaf': 1480}
# rmse 3.240
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 9, 'num_leaves': 1740, 'min_data_in_leaf': 1440}
# rmse 3.224
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 7, 'num_leaves': 2000, 'min_data_in_leaf': 1540}
# rmse 3.219
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 10, 'num_leaves': 940, 'min_data_in_leaf': 1720}
# rmse 3.229
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 5, 'num_leaves': 740, 'min_data_in_leaf': 1560}
# rmse 3.225
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 9, 'num_leaves': 1700, 'min_data_in_leaf': 1480}
# rmse 3.223
# 100%|██████████| 20/20 [30:05<00:00, 90.29s/trial, best loss: 3.2181074161973173]
# Training until validation scores don't improve for 150 rounds
# [25]	valid_0's custom_asymmetric_eval: 5.02762
# [50]	valid_0's custom_asymmetric_eval: 3.76437
# [75]	valid_0's custom_asymmetric_eval: 3.45579
# [100]	valid_0's custom_asymmetric_eval: 3.36988
# [125]	valid_0's custom_asymmetric_eval: 3.33763
# [150]	valid_0's custom_asymmetric_eval: 3.32084
# [175]	valid_0's custom_asymmetric_eval: 3.31023
# [200]	valid_0's custom_asymmetric_eval: 3.30228
# [225]	valid_0's custom_asymmetric_eval: 3.2972
# [250]	valid_0's custom_asymmetric_eval: 3.29235
# [275]	valid_0's custom_asymmetric_eval: 3.28891
# [300]	valid_0's custom_asymmetric_eval: 3.28491
# [325]	valid_0's custom_asymmetric_eval: 3.28134
# [350]	valid_0's custom_asymmetric_eval: 3.2783
# [375]	valid_0's custom_asymmetric_eval: 3.27596
# [400]	valid_0's custom_asymmetric_eval: 3.27333
# [425]	valid_0's custom_asymmetric_eval: 3.27132
# [450]	valid_0's custom_asymmetric_eval: 3.26931
# [475]	valid_0's custom_asymmetric_eval: 3.26717
# [500]	valid_0's custom_asymmetric_eval: 3.26516
# [525]	valid_0's custom_asymmetric_eval: 3.26408
# [550]	valid_0's custom_asymmetric_eval: 3.26213
# [575]	valid_0's custom_asymmetric_eval: 3.26055
# [600]	valid_0's custom_asymmetric_eval: 3.25915
# [625]	valid_0's custom_asymmetric_eval: 3.25727
# [650]	valid_0's custom_asymmetric_eval: 3.25586
# [675]	valid_0's custom_asymmetric_eval: 3.2543
# [700]	valid_0's custom_asymmetric_eval: 3.25303
# [725]	valid_0's custom_asymmetric_eval: 3.25129
# [750]	valid_0's custom_asymmetric_eval: 3.25013
# [775]	valid_0's custom_asymmetric_eval: 3.24879
# [800]	valid_0's custom_asymmetric_eval: 3.24713
# [825]	valid_0's custom_asymmetric_eval: 3.24594
# [850]	valid_0's custom_asymmetric_eval: 3.24484
# [875]	valid_0's custom_asymmetric_eval: 3.24362
# [900]	valid_0's custom_asymmetric_eval: 3.24234
# [925]	valid_0's custom_asymmetric_eval: 3.24103
# [950]	valid_0's custom_asymmetric_eval: 3.23979
# [975]	valid_0's custom_asymmetric_eval: 3.23905
# [1000]	valid_0's custom_asymmetric_eval: 3.23851
# [1025]	valid_0's custom_asymmetric_eval: 3.23772
# [1050]	valid_0's custom_asymmetric_eval: 3.23652
# [1075]	valid_0's custom_asymmetric_eval: 3.23556
# [1100]	valid_0's custom_asymmetric_eval: 3.23449
# [1125]	valid_0's custom_asymmetric_eval: 3.23375
# [1150]	valid_0's custom_asymmetric_eval: 3.23258
# [1175]	valid_0's custom_asymmetric_eval: 3.23149
# [1200]	valid_0's custom_asymmetric_eval: 3.23064
# [1225]	valid_0's custom_asymmetric_eval: 3.22992
# [1250]	valid_0's custom_asymmetric_eval: 3.2292
# [1275]	valid_0's custom_asymmetric_eval: 3.22862
# [1300]	valid_0's custom_asymmetric_eval: 3.22787
# [1325]	valid_0's custom_asymmetric_eval: 3.22697
# [1350]	valid_0's custom_asymmetric_eval: 3.22602
# [1375]	valid_0's custom_asymmetric_eval: 3.22496
# [1400]	valid_0's custom_asymmetric_eval: 3.22376
# Did not meet early stopping. Best iteration is:
# [1400]	valid_0's custom_asymmetric_eval: 3.22376
# Time elapsed 00:49:55.00
#
# Working on dept HOUSEHOLD_2
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 8, 'num_leaves': 880, 'min_data_in_leaf': 1960}
# rmse 0.497
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 6, 'num_leaves': 80, 'min_data_in_leaf': 1260}
# rmse 0.496
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 11, 'num_leaves': 780, 'min_data_in_leaf': 1920}
# rmse 0.497
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 1320, 'min_data_in_leaf': 920}
# rmse 0.494
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 8, 'num_leaves': 40, 'min_data_in_leaf': 1380}
# rmse 0.496
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 5, 'num_leaves': 800, 'min_data_in_leaf': 1140}
# rmse 0.495
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 9, 'num_leaves': 500, 'min_data_in_leaf': 580}
# rmse 0.500
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 5, 'num_leaves': 1780, 'min_data_in_leaf': 240}
# rmse 0.499
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 10, 'num_leaves': 220, 'min_data_in_leaf': 160}
# rmse 0.514
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 9, 'num_leaves': 120, 'min_data_in_leaf': 900}
# rmse 0.497
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 20, 'min_data_in_leaf': 1080}
# rmse 0.495
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 10, 'num_leaves': 760, 'min_data_in_leaf': 1940}
# rmse 0.497
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 7, 'num_leaves': 1520, 'min_data_in_leaf': 200}
# rmse 0.504
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 12, 'num_leaves': 1000, 'min_data_in_leaf': 1400}
# rmse 0.496
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 10, 'num_leaves': 1100, 'min_data_in_leaf': 140}
# rmse 0.515
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 4, 'num_leaves': 480, 'min_data_in_leaf': 1820}
# rmse 0.497
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 10, 'num_leaves': 880, 'min_data_in_leaf': 1140}
# rmse 0.497
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 5, 'num_leaves': 320, 'min_data_in_leaf': 320}
# rmse 0.496
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 9, 'num_leaves': 20, 'min_data_in_leaf': 1280}
# rmse 0.496
# {'boosting_type': 'gbdt', 'objective': 'tweedie', 'tweedie_variance_power': 1.1, 'metric': 'rmcustomse', 'subsample': 0.5, 'subsample_freq': 1, 'learning_rate': 0.03, 'feature_fraction': 0.5, 'max_bin': 100, 'n_estimators': 1400, 'boost_from_average': False, 'verbose': -1, 'max_depth': 9, 'num_leaves': 600, 'min_data_in_leaf': 340}
# rmse 0.505
# 100%|██████████| 20/20 [30:43<00:00, 92.20s/trial, best loss: 0.49409561963378845]
# Training until validation scores don't improve for 150 rounds
# [25]	valid_0's custom_asymmetric_eval: 0.688118
# [50]	valid_0's custom_asymmetric_eval: 0.618333
# [75]	valid_0's custom_asymmetric_eval: 0.601465
# [100]	valid_0's custom_asymmetric_eval: 0.596918
# [125]	valid_0's custom_asymmetric_eval: 0.595294
# [150]	valid_0's custom_asymmetric_eval: 0.594625
# [175]	valid_0's custom_asymmetric_eval: 0.594223
# [200]	valid_0's custom_asymmetric_eval: 0.593856
# [225]	valid_0's custom_asymmetric_eval: 0.593641
# [250]	valid_0's custom_asymmetric_eval: 0.593405
# [275]	valid_0's custom_asymmetric_eval: 0.593232
# [300]	valid_0's custom_asymmetric_eval: 0.593044
# [325]	valid_0's custom_asymmetric_eval: 0.59287
# [350]	valid_0's custom_asymmetric_eval: 0.592695
# [375]	valid_0's custom_asymmetric_eval: 0.59253
# [400]	valid_0's custom_asymmetric_eval: 0.592381
# [425]	valid_0's custom_asymmetric_eval: 0.592246
# [450]	valid_0's custom_asymmetric_eval: 0.592146
# [475]	valid_0's custom_asymmetric_eval: 0.592065
# [500]	valid_0's custom_asymmetric_eval: 0.591949
# [525]	valid_0's custom_asymmetric_eval: 0.591839
# [550]	valid_0's custom_asymmetric_eval: 0.591715
# [575]	valid_0's custom_asymmetric_eval: 0.591624
# [600]	valid_0's custom_asymmetric_eval: 0.591517
# [625]	valid_0's custom_asymmetric_eval: 0.591451
# [650]	valid_0's custom_asymmetric_eval: 0.591317
# [675]	valid_0's custom_asymmetric_eval: 0.591212
# [700]	valid_0's custom_asymmetric_eval: 0.591124
# [725]	valid_0's custom_asymmetric_eval: 0.591073
# [750]	valid_0's custom_asymmetric_eval: 0.591052
# [775]	valid_0's custom_asymmetric_eval: 0.590972
# [800]	valid_0's custom_asymmetric_eval: 0.590891
# [825]	valid_0's custom_asymmetric_eval: 0.590873
# [850]	valid_0's custom_asymmetric_eval: 0.590779
# [875]	valid_0's custom_asymmetric_eval: 0.590726
# [900]	valid_0's custom_asymmetric_eval: 0.590684
# [925]	valid_0's custom_asymmetric_eval: 0.59059
# [950]	valid_0's custom_asymmetric_eval: 0.590518
# [975]	valid_0's custom_asymmetric_eval: 0.5905
# [1000]	valid_0's custom_asymmetric_eval: 0.590476
# [1025]	valid_0's custom_asymmetric_eval: 0.590387
# [1050]	valid_0's custom_asymmetric_eval: 0.590311
# [1075]	valid_0's custom_asymmetric_eval: 0.590292
# [1100]	valid_0's custom_asymmetric_eval: 0.590235
# [1125]	valid_0's custom_asymmetric_eval: 0.590196
# [1150]	valid_0's custom_asymmetric_eval: 0.590152
# [1175]	valid_0's custom_asymmetric_eval: 0.590083
# [1200]	valid_0's custom_asymmetric_eval: 0.590079
# [1225]	valid_0's custom_asymmetric_eval: 0.59003
# [1250]	valid_0's custom_asymmetric_eval: 0.589969
# [1275]	valid_0's custom_asymmetric_eval: 0.589924
# [1300]	valid_0's custom_asymmetric_eval: 0.589901
# [1325]	valid_0's custom_asymmetric_eval: 0.589891
# [1350]	valid_0's custom_asymmetric_eval: 0.589853
# [1375]	valid_0's custom_asymmetric_eval: 0.589838
# [1400]	valid_0's custom_asymmetric_eval: 0.589809
# Did not meet early stopping. Best iteration is:
# [1389]	valid_0's custom_asymmetric_eval: 0.58979
# Time elapsed 00:49:45.00

# %%
# os.remove("/kaggle/working/params {dept_id}.txt")
# os.remove("/kaggle/working/params_{dept}.txt")
# # os.remove("/kaggle/working/params.txt")
# for i, dept in enumerate(np.unique(sales.dept_id)):
#     os.remove('/kaggle/working/'+dept+'_params2.txt')
